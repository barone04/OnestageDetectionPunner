# %%
from mobilenetv2 import mobilenetv2
from ptflops import get_model_complexity_info
import torch

# %%
model = mobilenetv2(compress_rate=[0.]+[0.5]*7)
with torch.cuda.device(0):
    get_model_complexity_info(model, (3, 224, 224))
# Out:
# MobileNetV2(
#   1.23 M, 100.000% Params, 126.45 MMac, 100.000% MACs,
#   (features): Sequential(
#     584.16 k, 47.680% Params, 125.81 MMac, 99.493% MACs,
#     (0): Sequential(
#       928, 0.076% Params, 12.04 MMac, 9.523% MACs,
#       (0): Conv2d(864, 0.071% Params, 10.84 MMac, 8.571% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, 0.005% Params, 802.82 KMac, 0.635% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.317% MACs, inplace=True)
#     )
#     (1): InvertedResidual(
#       896, 0.073% Params, 11.64 MMac, 9.206% MACs,
#       (conv): Sequential(
#         896, 0.073% Params, 11.64 MMac, 9.206% MACs,
#         (0): Conv2d(288, 0.024% Params, 3.61 MMac, 2.857% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
# ...

# %%
from resnet import resnet20

# %%
[0.]+[0.26]*11
# Out:
# [0.0, 0.26, 0.26, 0.26, 0.26, 0.26, 0.26, 0.26, 0.26, 0.26, 0.26, 0.26]

# %%
get_model_complexity_info(resnet20(num_classes=100, compress_rate=[0.]*12), (3, 224, 224))
# Out:
# ResNet(
#   278.32 k, 100.000% Params, 2.02 GMac, 99.960% MACs,
#   (embed): Sequential(
#     464, 0.167% Params, 24.08 MMac, 1.192% MACs,
#     (0): Conv2d(432, 0.155% Params, 21.68 MMac, 1.072% MACs, 3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, 0.011% Params, 1.61 MMac, 0.079% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.040% MACs, inplace=True)
#   )
#   (layer1): Sequential(
#     14.02 k, 5.036% Params, 703.27 MMac, 34.796% MACs,
#     (0): BasicBlock(
#       4.67 k, 1.679% Params, 234.42 MMac, 11.599% MACs,
#       (conv1): Conv2d(2.3 k, 0.828% Params, 115.61 MMac, 5.720% MACs, 16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, 0.011% Params, 1.61 MMac, 0.079% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
resnet20(num_classes=100, compress_rate=[0.]*4+[0.25]*3+[0.9]*5)
# Out:
# ResNet(
#   (embed): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
from resnet import adapt_channel

# %%
adapt_channel([0.]*12, [3, 3, 3])
# Out:
# ([16, 16, 16, 16, 32, 32, 32, 64, 64, 64],
#  [16, 16, 16, 32, 32, 32, 64, 64, 64])

# %%
adapt_channel([0.]+[0.26]*11, [3, 3, 3])
# Out:
# ([16, 11, 11, 11, 23, 23, 23, 47, 47, 47],
#  [11, 11, 11, 23, 23, 23, 47, 47, 47])

# %%
adapt_channel([0.]+[0.]*2+[0.5]+[0.]*2+[0.5]+[0.5]*2+[0.6]*3, [3, 3, 3])
# Out:
# ([16, 16, 16, 16, 32, 32, 32, 32, 32, 32], [8, 16, 16, 16, 16, 16, 25, 25, 25])

# %%
resnet20(num_classes=100, compress_rate=[0.]+[0.]*2+[0.5]+[0.]*2+[0.5]+[0.5]*2+[0.6]*3)
# Out:
# ResNet(
#   (embed): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...
